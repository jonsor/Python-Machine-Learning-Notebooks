# %% [markdown]
# # Assignment 3 Overview

# %%
import pandas as pd

eng_short = pd.read_excel('Engelsberger_short.xlsx')

print(eng_short.shape)
eng_short.head()
# Out:
# (641, 5)
#                                                             relative peptide intensity levels (time)  \
# Accession (AGI code) Sequence with modifications treatment                                  0.000000
# AT1G09180.1          YYLGL(pT)NFTTGK             NO3                                        0.079901
# AT5G45380.1          VVEAYA(pS)GDEDVDVPAEELREEK  NO3                                        0.990037
# AT3G08710.1          VTSIIDSVPE(pS)PQRP          NO3                                        0.926784
# AT5G24840.1          VTE(pY)VKER                 NO3                                        1.000000
#
#                                                             Unnamed: 1  \
# Accession (AGI code) Sequence with modifications treatment    3.000000
# AT1G09180.1          YYLGL(pT)NFTTGK             NO3          0.746354
# AT5G45380.1          VVEAYA(pS)GDEDVDVPAEELREEK  NO3          0.602870
# ...

# %%
eng_short.describe()
# Out:
#        relative peptide intensity levels (time)  Unnamed: 1  Unnamed: 2  \
# count                                478.000000  186.000000  188.000000
# mean                                   0.867641    0.688770    0.699779
# std                                    0.269367    0.354611    0.490418
# min                                    0.000000    0.003050    0.000953
# 25%                                    0.924019    0.474640    0.288663
# 50%                                    1.000000    0.730921    0.871290
# 75%                                    1.000000    1.000000    1.000000
# max                                    1.000000    3.000000    5.000000
#
#        Unnamed: 3  Unnamed: 4
# count  234.000000  169.000000
# mean     0.736330    0.790762
# std      0.704088    2.290998
# min      0.000107    0.000151
# 25%      0.400540    0.245539
# 50%      0.896080    0.775909
# 75%      1.000000    1.000000
# max     10.000000   30.000000

# %%
eng_full = pd.read_excel('Engelsberger_full.xlsx')

print(eng_full.shape)
eng_full.head()
# Out:
# (2133, 16)
#                                                             relative peptide intensity levels (time)  \
# Accession (AGI code) Sequence with modifications treatment                                  0.000000
# AT1G09180.1          YYLGL(pT)NFTTGK             NO3                                        0.079901
# AT5G45380.1          VVEAYA(pS)GDEDVDVPAEELREEK  NO3                                        0.990037
# AT3G08710.1          VTSIIDSVPE(pS)PQRP          NO3                                        0.926784
# AT5G24840.1          VTE(pY)VKER                 NO3                                        1.000000
#
#                                                             Unnamed: 1  \
# Accession (AGI code) Sequence with modifications treatment    3.000000
# AT1G09180.1          YYLGL(pT)NFTTGK             NO3          0.746354
# AT5G45380.1          VVEAYA(pS)GDEDVDVPAEELREEK  NO3          0.602870
# ...

# %%
eng_full.describe()
# Out:
#        relative peptide intensity levels (time)  Unnamed: 1  Unnamed: 2  \
# count                               1284.000000  540.000000  689.000000
# mean                                   0.876842    0.770186    0.703896
# std                                    0.264310    0.333038    0.398044
# min                                    0.000000    0.000091    0.000230
# 25%                                    1.000000    0.577009    0.372578
# 50%                                    1.000000    1.000000    0.915617
# 75%                                    1.000000    1.000000    1.000000
# max                                    1.000000    3.000000    5.000000
#
#        Unnamed: 3  Unnamed: 4
# count  730.000000  597.000000
# mean     0.663316    0.703845
# std      0.507061    1.257180
# min      0.000050    0.000120
# 25%      0.312835    0.335272
# 50%      0.758678    0.798640
# 75%      1.000000    1.000000
# max     10.000000   30.000000

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import Imputer

imp = Imputer(missing_values='NaN', strategy='mean', axis=1)
cleaned_data = imp.fit_transform(original_data)


# keep the first two principal components of the data
pca = PCA(n_components=2)
# fit PCA model to breast cancer data
pca.fit(eng_short)
# transform data onto the first two principal components
X_pca = pca.transform(eng_short)
print("Original shape: {}".format(str(eng_short.shape)))
print("Reduced shape: {}".format(str(X_pca.shape)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-a320508ba276> in <module>()
#       3 pca = PCA(n_components=2)
#       4 # fit PCA model to breast cancer data
# ----> 5 pca.fit(eng_short)
#       6 # transform data onto the first two principal components
#       7 X_pca = pca.transform(eng_short)
#
# ~\Anaconda3\lib\site-packages\sklearn\decomposition\pca.py in fit(self, X, y)
#     327             Returns the instance itself.
#     328         """
# --> 329         self._fit(X)
#     330         return self
#     331
#
# ~\Anaconda3\lib\site-packages\sklearn\decomposition\pca.py in _fit(self, X)
#     368
#     369         X = check_array(X, dtype=[np.float64, np.float32], ensure_2d=True,
# --> 370                         copy=self.copy)
#     371
#     372         # Handle n_components==None
#
# ...
